# %%
import zarr
import numpy as np
import anndata
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import dask
from pyseq import image_analysis as ia
import warnings
warnings.filterwarnings('ignore')
from dask.distributed import Client
import numba
import joblib
import skimage
import time
from joblib import Parallel, delayed
from joblib import parallel_backend
from dask.distributed import progress
# %run /gpfs/commons/home/jsingh/util_pyseq.ipynb

# %%
#Loading Data
im = ia.get_HiSeqImages(image_path = 'zarrs/m387ntga2.zarr')
labels = skimage.io.imread('/gpfs/commons/groups/nygcfaculty/PySeq/20210428_mouse_genotype_2/segmented_sections/m387ntga2_labels.tiff')
labels = dask.array.asarray(labels)
# Out:
# ImageAnalysis::Opened m387ntga2

# %%
#format = one_z_plane_obj_step_channel_cycle
array_object_list = []
name_object_list = []
for i in im.im['channel'].values:
    for j in im.im['cycle'].values:
        #for k #in im.im['obj_step'].values[1]:
            k = 8028
            name = "one_x_plane_"+str(i)+"_"+str(j)+"_"+str(k)
            name_object_list.append(name)
            nme = im.im.sel(obj_step = k, cycle=j, channel = i)
            array_object_list.append(nme)

# %%
############ INITIATING CLUSTER ####################

# %%
def get_cluster(queue_name = 'pe2', log_dir=None):
    """ Make dask cluster w/ workers = 2 cores, 32 G mem, and 1 hr wall time.

        return cluster, client
    """

    if log_dir is None:
        log_dir = join(getcwd(),'dask_logs')
        makedirs(log_dir, exist_ok=True)

    cluster = SLURMCluster(
                queue = queue_name, 
                cores = 12 ,
                memory = '128G',
                walltime='1:00:00',
                log_directory=log_dir)
                #extra=["--lifetime", "55m", "--lifetime-stagger", "4m"])
    client = Client(cluster)

    return cluster, client

cluster, client = get_cluster()

# %%
cluster.scale(15)

# %%
print(cluster.dashboard_link) # Or specify cores or memory directly
# Out:
# http://10.4.202.10:42570/status

# %%
plane = array_object_list[0] #sample plane

# %%
#Way 1: Using Data As Is (No Persit) with Dask Futures

plane = array_object_list[0]
def get_pixels(lab):
    m = plane.values[labels == lab+1].mean()
    return m

futures = client.map(get_pixels, range(5))
progress(futures)

result_list = np.zeros(20)
for i in range(len(futures)):
    result_list[i] = futures[i].result()

# %%
#Way 2: Using with Dask Persist with Dask Futures

plane_persisted = array_object_list[0].persist()
def get_pixels(lab):
    m = plane_persisted.values[labels == lab+1].mean()
    return m
from dask.distributed import progress
futures = client.map(get_pixels, range(5))
progress(futures)


result_list = np.zeros(20)
for i in range(len(futures)):
    result_list[i] = futures[i].result()

# %%
# %%time
#Way 3: Computing the same using dask compute without persisting Data

def get_pixels(lab):
    m = plane.values[labels == lab+1].mean()
    return m

with parallel_backend('dask',scheduler_host=cluster.scheduler._address):
    results = Parallel(n_jobs=-1)(delayed(get_pixels_persisted)(lab) for lab in range(100))

# %%
# %%time
#Way 4: Computing way 3 with persist

def get_pixels(lab):
    m = plane_persisted.values[labels == lab+1].mean()
    return m

with parallel_backend('dask',scheduler_host=cluster.scheduler._address):
    results = Parallel(n_jobs=-1)(delayed(get_pixels_persisted)(lab) for lab in range(100))

# %%
dk = dask.array.asarray(plane.values)

# %%
#Way 5: Dask Masked Array
dk = dask.array.asarray(plane.values)
def get_pixels(lab):
    m = dask.array.ma.masked_array(dk,np.squeeze([labels == lab]))
    mv = dask.array.mean(m)
    return mv

futures = client.map(get_pixels, range(5))

result_list = np.zeros(20)
for i in range(len(futures)):
    result_list[i] = futures[i].result()

# %%
#Way 6: Dask Masked Array With Persist 
dk = dask.array.asarray(persisted_plane.values)
def get_pixels(lab):
    m = dask.array.ma.masked_array(dk,np.squeeze([labels == lab]))
    mv = dask.array.mean(m)
    return mv

futures = client.map(get_pixels, range(5))

result_list = np.zeros(20)
for i in range(len(futures)):
    result_list[i] = futures[i].result()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 2>()
#       1 #Way 6: Dask Masked Array With Persist
# ----> 2 dk = dask.array.asarray(persisted_plane.values)
#       3 def get_pixels(lab):
#       4     m = dask.array.ma.masked_array(dk,np.squeeze([labels == lab]))
#
# NameError: name 'persisted_plane' is not defined

# %%
#Way 5 using joblib 
def get_pixels(lab):
    m = dask.array.ma.masked_array(dk,np.squeeze([labels == lab]))
    mv = dask.array.mean(m)
    return mv

with parallel_backend('dask',scheduler_host=cluster.scheduler._address):
    results = Parallel(n_jobs=-1)(delayed(get_pixels)(lab) for lab in range(100))
# Out:
# 2022-06-22 23:50:17,858 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092088' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,902 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092089' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,904 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092090' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,905 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092091' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,907 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092092' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,910 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092107' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,912 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092108' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,913 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092109' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,915 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092110' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,916 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092111' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,917 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092112' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,918 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092113' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,919 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092114' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,920 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092115' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,922 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092116' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,923 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092117' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,924 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092118' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,925 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092119' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,926 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092120' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,927 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092121' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,927 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092122' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,929 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092123' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,930 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092124' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,932 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092125' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,933 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092126' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,934 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092127' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,935 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092128' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,936 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092129' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,937 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092130' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,939 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092131' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,940 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092132' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,941 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092133' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,942 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092134' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,960 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092135' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
# ...
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,971 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092145' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,973 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092146' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,974 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092147' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,975 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092148' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:50:17,976 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7fb5a03a0880>>, <Task finished name='Task-2092149' coro=<DaskDistributedBackend.apply_async.<locals>.f() done, defined at /gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py:323> exception=TypeError('Delayed objects of unspecified length are not iterable')>)
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 324, in f
#     batch, tasks = await self._to_func_args(func)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/joblib/_dask.py", line 310, in _to_func_args
#     for f, args, kwargs in func.items:
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/dask/delayed.py", line 581, in __iter__
#     raise TypeError("Delayed objects of unspecified length are not iterable")
# TypeError: Delayed objects of unspecified length are not iterable
# 2022-06-22 23:53:36,009 - bokeh.core.property.validation - ERROR - 'str' object has no attribute 'text'
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 355, in update
#     self.root.title.text = title
# AttributeError: 'str' object has no attribute 'text'
# 2022-06-22 23:53:36,012 - bokeh.application.handlers.function - ERROR - 'str' object has no attribute 'text'
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 3915, in status_doc
#     cluster_memory.update()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 355, in update
#     self.root.title.text = title
# AttributeError: 'str' object has no attribute 'text'
# 2022-06-22 23:53:36,013 - tornado.application - ERROR - Uncaught exception GET /status (192.168.101.162)
# HTTPServerRequest(protocol='http', host='10.4.202.10:8787', method='GET', uri='/status', version='HTTP/1.1', remote_ip='192.168.101.162')
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/server/views/doc_handler.py", line 54, in get
#     session = await self.get_session()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 3915, in status_doc
#     cluster_memory.update()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 355, in update
#     self.root.title.text = title
# AttributeError: 'str' object has no attribute 'text'
# 2022-06-22 23:53:48,732 - bokeh.core.property.validation - ERROR - 'str' object has no attribute 'text'
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 355, in update
#     self.root.title.text = title
# AttributeError: 'str' object has no attribute 'text'
# 2022-06-22 23:53:48,737 - bokeh.application.handlers.function - ERROR - 'str' object has no attribute 'text'
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 3915, in status_doc
#     cluster_memory.update()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 355, in update
#     self.root.title.text = title
# AttributeError: 'str' object has no attribute 'text'
# 2022-06-22 23:53:48,739 - tornado.application - ERROR - Uncaught exception GET /status (192.168.101.162)
# HTTPServerRequest(protocol='http', host='10.4.202.10:8787', method='GET', uri='/status', version='HTTP/1.1', remote_ip='192.168.101.162')
# Traceback (most recent call last):
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/tornado/web.py", line 1704, in _execute
#     result = await result
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/server/views/doc_handler.py", line 54, in get
#     session = await self.get_session()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/server/views/session_handler.py", line 144, in get_session
#     session = await self.application_context.create_session_if_needed(session_id, self.request, token)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/server/contexts.py", line 243, in create_session_if_needed
#     self._application.initialize_document(doc)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/application/application.py", line 194, in initialize_document
#     h.modify_document(doc)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/application/handlers/function.py", line 143, in modify_document
#     self._func(doc)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 3915, in status_doc
#     cluster_memory.update()
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/bokeh/core/property/validation.py", line 95, in func
#     return input_function(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/utils.py", line 767, in wrapper
#     return func(*args, **kwargs)
#   File "/gpfs/commons/home/jsingh/.conda/envs/spatial/lib/python3.9/site-packages/distributed/dashboard/components/scheduler.py", line 355, in update
#     self.root.title.text = title
# AttributeError: 'str' object has no attribute 'text'
#
# KeyboardInterrupt

# %%
#Way x : Dask image functions
import dask_image

index = list(range(11232))
del index[0]

ar = dask_image.ndmeasure.labeled_comprehension(image = plane, 
                                                label_image = labels, index = index, func = dask_image.ndmeasure.mean,
                                                out_dtype = float, default = None, pass_positions = False)
v = ar.compute()

# %%
#ADJUSTING TIMEOUT

# %%
client.close()
cluster.close()
